# %% [markdown]
# # A* Motion Planning

# %%
# The autoreload extension will automatically load in new code as you edit files, 
# so you don't need to restart the kernel every time
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from P1_astar import DetOccupancyGrid2D, AStar
from utils import generate_planning_problem

# %% [markdown]
# ## Simple Environment
# ### Workspace
# (Try changing this and see what happens)

# %%
width = 10
height = 10
obstacles = [((6,7),(8,8)),((2,2),(4,3)),((2,5),(4,7)),((6,3),(8,5))]
occupancy = DetOccupancyGrid2D(width, height, obstacles)

# %% [markdown]
# ### Starting and final positions
# (Try changing these and see what happens)

# %%
x_init = (1, 1)
x_goal = (9, 9)

# %% [markdown]
# ### Run A* planning

# %%
astar = AStar((0, 0), (width, height), x_init, x_goal, occupancy)
if not astar.solve():
    print "No path found"
else:
    plt.rcParams['figure.figsize'] = [5, 5]
    astar.plot_path()
    astar.plot_tree()
# Out:
# &lt;Figure size 360x360 with 1 Axes&gt;

# %% [markdown]
# ## Random Cluttered Environment
# ### Generate workspace, start and goal positions
# (Try changing these and see what happens)

# %%
width = 100
height = 100
num_obs = 25
min_size = 5
max_size = 30

occupancy, x_init, x_goal = generate_planning_problem(width, height, num_obs, min_size, max_size)

# %% [markdown]
# ### Run A* planning

# %%
astar = AStar((0, 0), (width, height), x_init, x_goal, occupancy)
if not astar.solve():
    print "No path found"
else:
    plt.rcParams['figure.figsize'] = [10, 10]
    astar.plot_path()
    astar.plot_tree(point_size=2)
# Out:
# ValueErrorTraceback (most recent call last)
# &lt;ipython-input-15-112d5faaba03&gt; in &lt;module&gt;()
#       1 astar = AStar((0, 0), (width, height), x_init, x_goal, occupancy)
# ----&gt; 2 if not astar.solve():
#       3     print &quot;No path found&quot;
#       4 else:
#       5     plt.rcParams[&#39;figure.figsize&#39;] = [10, 10]
#
# /home/james/Documents/AA274A_HW2/P1_astar.py in solve(self)
#     182         ########## Code starts here ##########
#     183         while(self.open_set &gt; 0):
# --&gt; 184             x_current = self.find_best_est_cost_through()
#     185             if x_current == self.x_goal:
#     186                 return self.reconstruct_path()
#
# /home/james/Documents/AA274A_HW2/P1_astar.py in find_best_est_cost_through(self)
#     126         Output: A tuple, the state found in open_set that has the lowest est_cost_through
#     127         &quot;&quot;&quot;
# --&gt; 128         return min(self.open_set, key=lambda x: self.est_cost_through[x])
#     129
#     130     def reconstruct_path(self):
#
# ValueError: min() arg is an empty sequence
